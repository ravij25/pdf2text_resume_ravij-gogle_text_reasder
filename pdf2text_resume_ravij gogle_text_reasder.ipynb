# %%
# !pip install PyPDF2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# note the capitalization
import PyPDF2

# %%
# Notice we read it as a binary with 'rb'
f = open(r'C:\Users\admn\Downloads\CV_ravij_final_10.pdf','rb')

# %%
pdf_reader = PyPDF2.PdfFileReader(f)

# %%
pdf_reader.numPages
# Out:
# 3

# %%
page_one = pdf_reader.getPage(0)
page_two = pdf_reader.getPage(1)
page_three = pdf_reader.getPage(2)

# %%
page_one_text = page_one.extractText()
page_two_text = page_two.extractText()
page_3_text = page_three.extractText()

# %%
page_one_text
# Out:
# 'RA VI JONN AL A GADD A\n,\ni@\nOCON T A C T\nr a vijonnas@gmail.com\n9010783548\nHNO-12-10-587-50/22 RO AD N\nO1, INDIRA N A GAR COL ON Y W\nARASIGUD A, SECUNDERABAD\nTEL ANGAN A ST A TE INDI A, PIN\n500061\nwww .link edin.com/in/r a vi-jonn\nalagadda-62758436\nPERSON AL DE T AILS\nDate of Bir th : 20/07/1985\nMarital Status : Married\nNationality : Indian\nSKILLS\nMachine learning,Ar tiﬁcial\nintelligence, Deep Learning,\nP ython P andas, Nump y , SciKit-\nLearn, Matplotlib, Seaborn, ,\nSciP y , K er as, LSTM, CNN, NLP ,\nTENSORFL OW , P yT or ch\nRegr ession, Clustering, CNN,\nClassiﬁcation, Descision T r ee.,\nRecommendations, Naïv e Ba y es,\nC, C++, SQL\nGEOPH Y SICAL SOF T W ARES\nGEOSOF T , RAM A G, RES2D VIN,\nMESA, SPW , SURFER, PROM AX\nAr cGIS,QGIS\nT eaching experience ( 2014-\n2021) T eaching GRA VI T Y ,\nM A GNE TIC AND ELEC TRO\nM A GNE TIC ME THODS FOR M.Sc\nGEOPH Y SICS students.2017-\n2022\n2008\n2006OBJEC TIVE\nLooking for a Data scientist position, ambitious and
# ...

# %%
page_two_text
# Out:
# '01/09/2019\n-\n30/08/2022\n30/12/2015\n-\n30/07/2019\n05/07/2013\n-\n30/12/2015\n16/06/2008\n-\n30/05/2013F ak e news detection using langauge pr ocessing Deep learning\nmodel\nNatur al Language pr ocessing\xa0\nHealth Data analysis\nLogistic r egr ession\xa0\nNaïv e Ba y es\xa0\nDecision tr ees\xa0\n \n3D seismic data acquisition pr oject in Digboi ar ea, ASSAM\nSeismic data acquisition, pr ocessing, analysis.\nCrustal e v aluation and r esour ces potential management in Nor th\neastern Dhar war Cr at on, T elangana state, INDI A\nCollection of magnetic, electr omagnetic, electrical data pr ocessing\nand interpr etation. Remote sensing Data analysis.\nUnder UPE-CAR T -ES, Osmania Univ ersity sponsor ed b y UGC\xa0\nEXPERIENCE\nDIGIKS INFO TECH PVT L TD\nData Scientist\nPr eparing Data science course material\nP ython\xa0\nMachine learning models\nDeep learning models\nNLP , K er as, ANN, CNN, RNN\nOsmania Univ ersity\nSenior Resear ch F ellow\nW orking on PhD entitled " Application
# ...

# %%
page_3_text
# Out:
# '2. Ra vi, Jonnalagadda, Ram Raj Mathur , and A. Sridhar . "Remote\nsensing and VLF-EM \ntechniques t o delineate lampr oites in V attikode, Gundr apally and\nMar epally ar eas, \nNalgonda district, T elangana state, India. " Journal of Applied\nGeochemistr y 21.3 \n(2019): 356-363.\n3. Jonnalagadda, Ra vi, and Ram Raj Mathur . " Application of 2D\nResistivity Modelling t o \nDelineate Lampr oites in P ar ts of Nor th ‑ Eastern Dhar war Cr at on. "\n(2022).'

# %%
f = open(r'C:\Users\admn\Downloads\CV_ravij_final_10.pdf','rb')

# List of every page's text.
# The index will correspond to the page number.
pdf_text = [0]  # zero is a placehoder to make page 1 = index 1

pdf_reader = PyPDF2.PdfFileReader(f)

for p in range(pdf_reader.numPages):
    
    page = pdf_reader.getPage(p)
    
    pdf_text.append(page.extractText())

f.close()

# %%
pdf_text
# Out:
# [0,
# ...

# %%
print(pdf_text[1])
# Out:
# RA VI JONN AL A GADD A
# ,
# i@
# OCON T A C T
# r a vijonnas@gmail.com
# 9010783548
# HNO-12-10-587-50/22 RO AD N
# O1, INDIRA N A GAR COL ON Y W
# ARASIGUD A, SECUNDERABAD
# TEL ANGAN A ST A TE INDI A, PIN
# 500061
# www .link edin.com/in/r a vi-jonn
# alagadda-62758436
# PERSON AL DE T AILS
# Date of Bir th : 20/07/1985
# Marital Status : Married
# Nationality : Indian
# SKILLS
# Machine learning,Ar tiﬁcial
# intelligence, Deep Learning,
# P ython P andas, Nump y , SciKit-
# Learn, Matplotlib, Seaborn, ,
# SciP y , K er as, LSTM, CNN, NLP ,
# TENSORFL OW , P yT or ch
# Regr ession, Clustering, CNN,
# Classiﬁcation, Descision T r ee.,
# Recommendations, Naïv e Ba y es,
# C, C++, SQL
# GEOPH Y SICAL SOF T W ARES
# GEOSOF T , RAM A G, RES2D VIN,
# MESA, SPW , SURFER, PROM AX
# Ar cGIS,QGIS
# T eaching experience ( 2014-
# 2021) T eaching GRA VI T Y ,
# M A GNE TIC AND ELEC TRO
# M A GNE TIC ME THODS FOR M.Sc
# GEOPH Y SICS students.2017-
# 2022
# 2008
# 2006OBJEC TIVE
# ...

# %%
# !pip install gTTS
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from gtts import gTTS
tts = gTTS(pdf_text[1])
tts.save('output.mp3')

# %%
import IPython
file = "./output.mp3"# change the folder and file accordingly 
IPython.display.display(IPython.display.Audio(file))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !python -m pip install pymongo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pymongo

client=pymongo.MongoClient('mongodb://localhost:27017/')

mydb=client['mypdf']
resume=mydb.resmue

# %%
resmue1=pdf_text[1]

# %%
resmue1
# Out:
# 'RA VI JONN AL A GADD A\n,\ni@\nOCON T A C T\nr a vijonnas@gmail.com\n9010783548\nHNO-12-10-587-50/22 RO AD N\nO1, INDIRA N A GAR COL ON Y W\nARASIGUD A, SECUNDERABAD\nTEL ANGAN A ST A TE INDI A, PIN\n500061\nwww .link edin.com/in/r a vi-jonn\nalagadda-62758436\nPERSON AL DE T AILS\nDate of Bir th : 20/07/1985\nMarital Status : Married\nNationality : Indian\nSKILLS\nMachine learning,Ar tiﬁcial\nintelligence, Deep Learning,\nP ython P andas, Nump y , SciKit-\nLearn, Matplotlib, Seaborn, ,\nSciP y , K er as, LSTM, CNN, NLP ,\nTENSORFL OW , P yT or ch\nRegr ession, Clustering, CNN,\nClassiﬁcation, Descision T r ee.,\nRecommendations, Naïv e Ba y es,\nC, C++, SQL\nGEOPH Y SICAL SOF T W ARES\nGEOSOF T , RAM A G, RES2D VIN,\nMESA, SPW , SURFER, PROM AX\nAr cGIS,QGIS\nT eaching experience ( 2014-\n2021) T eaching GRA VI T Y ,\nM A GNE TIC AND ELEC TRO\nM A GNE TIC ME THODS FOR M.Sc\nGEOPH Y SICS students.2017-\n2022\n2008\n2006OBJEC TIVE\nLooking for a Data scientist position, ambitious and
# ...
